# %% [markdown]
# # Набор данных для выявления спам-писем

# %% [markdown]
# # Описание задачи

# %% [markdown]
# Этот набор данных содержит характеристики электронных писем. Он включает в себя такие признкаки, как частота появления в письме различных слов, отдельных символов, длины текста в заглавной раскладке. В зависимости от значений этих признаков письмо или определяется в категорию "спам", или нет.

# %% [markdown]
# # Чтение данных

# %% [markdown]
# Подключение необходимых библиотек

# %%
import numpy             
import pandas # для таблиц
import matplotlib.pyplot as pyplot            
import seaborn # для визуализации
import sklearn

# %% [markdown]
# Загрузка данных

# %%
url = 'https://github.com/molevmichail/machine-learning/blob/main/spambase.csv'
data = pandas.read_csv(url)
data.shape
# Out:
# (4601, 58)

# %% [markdown]
# В текущем наборе данных содержится информация о 4601-м объектах, разделённая на 57 признаков.

# %% [markdown]
# Чтение данных

# %%
data
# Out:
#       word_freq_make    word_freq_address    word_freq_all    word_freq_3d   \
# 0                0.00                 0.64             0.64             0.0
# 1                0.21                 0.28             0.50             0.0
# 2                0.06                 0.00             0.71             0.0
# 3                0.00                 0.00             0.00             0.0
# 4                0.00                 0.00             0.00             0.0
# ...               ...                  ...              ...             ...
# 4596             0.31                 0.00             0.62             0.0
# 4597             0.00                 0.00             0.00             0.0
# 4598             0.30                 0.00             0.30             0.0
# 4599             0.96                 0.00             0.00             0.0
# 4600             0.00                 0.00             0.65             0.0
#
#        word_freq_our    word_freq_over    word_freq_remove   \
# 0                0.32              0.00                0.00
# 1                0.14              0.28                0.21
# 2                1.23              0.19                0.19
# 3                0.63              0.00                0.31
# 4                0.63              0.00                0.31
# ...               ...               ...                 ...
# 4596             0.00              0.31                0.00
# 4597             0.00              0.00                0.00
# 4598             0.00              0.00                0.00
# 4599             0.32              0.00                0.00
# 4600             0.00              0.00                0.00
#
#        word_freq_internet    word_freq_order    word_freq_mail   ...  \
# 0                     0.00               0.00              0.00  ...
# 1                     0.07               0.00              0.94  ...
# 2                     0.12               0.64              0.25  ...
# 3                     0.63               0.31              0.63  ...
# 4                     0.63               0.31              0.63  ...
# ...                    ...                ...               ...  ...
# 4596                  0.00               0.00              0.00  ...
# 4597                  0.00               0.00              0.00  ...
# 4598                  0.00               0.00              0.00  ...
# 4599                  0.00               0.00              0.00  ...
# 4600                  0.00               0.00              0.00  ...
#
#        char_freq_;    char_freq_(    char_freq_[    char_freq_!   \
# 0             0.000          0.000            0.0          0.778
# 1             0.000          0.132            0.0          0.372
# 2             0.010          0.143            0.0          0.276
# 3             0.000          0.137            0.0          0.137
# 4             0.000          0.135            0.0          0.135
# ...             ...            ...            ...            ...
# 4596          0.000          0.232            0.0          0.000
# 4597          0.000          0.000            0.0          0.353
# 4598          0.102          0.718            0.0          0.000
# 4599          0.000          0.057            0.0          0.000
# 4600          0.000          0.000            0.0          0.125
#
#        char_freq_$    char_freq_#    capital_run_length_average   \
# 0             0.000          0.000                         3.756
# 1             0.180          0.048                         5.114
# 2             0.184          0.010                         9.821
# 3             0.000          0.000                         3.537
# 4             0.000          0.000                         3.537
# ...             ...            ...                           ...
# 4596          0.000          0.000                         1.142
# 4597          0.000          0.000                         1.555
# 4598          0.000          0.000                         1.404
# 4599          0.000          0.000                         1.147
# 4600          0.000          0.000                         1.250
#
#        capital_run_length_longest    capital_run_length_total    is_spam
# 0                               61                         278         1
# 1                              101                        1028         1
# 2                              485                        2259         1
# 3                               40                         191         1
# 4                               40                         191         1
# ...                            ...                         ...       ...
# 4596                             3                          88         0
# 4597                             4                          14         0
# 4598                             6                         118         0
# 4599                             5                          78         0
# 4600                             5                          40         0
#
# [4601 rows x 58 columns]

# %%
data.columns
# Out:
# Index(['word_freq_make ', ' word_freq_address ', ' word_freq_all ',
#        ' word_freq_3d ', ' word_freq_our ', ' word_freq_over ',
#        ' word_freq_remove ', ' word_freq_internet ', ' word_freq_order ',
#        ' word_freq_mail ', ' word_freq_receive ', ' word_freq_will ',
#        ' word_freq_people ', ' word_freq_report ', ' word_freq_addresses ',
#        ' word_freq_free ', ' word_freq_business ', ' word_freq_email ',
#        ' word_freq_you ', ' word_freq_credit ', ' word_freq_your ',
#        ' word_freq_font ', ' word_freq_000 ', ' word_freq_money ',
#        ' word_freq_hp ', ' word_freq_hpl ', ' word_freq_george ',
#        ' word_freq_650 ', ' word_freq_lab ', ' word_freq_labs ',
#        ' word_freq_telnet ', ' word_freq_857 ', ' word_freq_data ',
#        ' word_freq_415 ', ' word_freq_85 ', ' word_freq_technology ',
#        ' word_freq_1999 ', ' word_freq_parts ', ' word_freq_pm ',
#        ' word_freq_direct ', ' word_freq_cs ', ' word_freq_meeting ',
#        ' word_freq_original ', ' word_freq_project ', ' word_freq_re ',
#        ' word_freq_edu ', ' word_freq_table ', ' word_freq_conference ',
#        ' char_freq_; ', ' char_freq_( ', ' char_freq_[ ', ' char_freq_! ',
#        ' char_freq_$ ', ' char_freq_# ', ' capital_run_length_average ',
#        ' capital_run_length_longest ', ' capital_run_length_total ',
#        ' is_spam'],
#       dtype='object')

# %% [markdown]
# # Визуализация данных и вычисление основных характеристик

# %% [markdown]
# Получение информации о количественных признаках

# %%
data.describe()
# Out:
#        word_freq_make    word_freq_address    word_freq_all    word_freq_3d   \
# count      4601.000000          4601.000000      4601.000000     4601.000000
# mean          0.104553             0.213015         0.280656        0.065425
# std           0.305358             1.290575         0.504143        1.395151
# min           0.000000             0.000000         0.000000        0.000000
# 25%           0.000000             0.000000         0.000000        0.000000
# 50%           0.000000             0.000000         0.000000        0.000000
# 75%           0.000000             0.000000         0.420000        0.000000
# max           4.540000            14.280000         5.100000       42.810000
#
#         word_freq_our    word_freq_over    word_freq_remove   \
# count      4601.000000       4601.000000         4601.000000
# mean          0.312223          0.095901            0.114208
# std           0.672513          0.273824            0.391441
# min           0.000000          0.000000            0.000000
# 25%           0.000000          0.000000            0.000000
# 50%           0.000000          0.000000            0.000000
# 75%           0.380000          0.000000            0.000000
# max          10.000000          5.880000            7.270000
#
#         word_freq_internet    word_freq_order    word_freq_mail   ...  \
# count           4601.000000        4601.000000       4601.000000  ...
# mean               0.105295           0.090067          0.239413  ...
# std                0.401071           0.278616          0.644755  ...
# min                0.000000           0.000000          0.000000  ...
# 25%                0.000000           0.000000          0.000000  ...
# 50%                0.000000           0.000000          0.000000  ...
# 75%                0.000000           0.000000          0.160000  ...
# max               11.110000           5.260000         18.180000  ...
#
#         char_freq_;    char_freq_(    char_freq_[    char_freq_!   \
# count    4601.000000    4601.000000    4601.000000    4601.000000
# mean        0.038575       0.139030       0.016976       0.269071
# std         0.243471       0.270355       0.109394       0.815672
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.065000       0.000000       0.000000
# 75%         0.000000       0.188000       0.000000       0.315000
# max         4.385000       9.752000       4.081000      32.478000
#
#         char_freq_$    char_freq_#    capital_run_length_average   \
# count    4601.000000    4601.000000                   4601.000000
# mean        0.075811       0.044238                      5.191515
# std         0.245882       0.429342                     31.729449
# min         0.000000       0.000000                      1.000000
# 25%         0.000000       0.000000                      1.588000
# 50%         0.000000       0.000000                      2.276000
# 75%         0.052000       0.000000                      3.706000
# max         6.003000      19.829000                   1102.500000
#
#         capital_run_length_longest    capital_run_length_total       is_spam
# count                   4601.000000                 4601.000000  4601.000000
# mean                      52.172789                  283.289285     0.394045
# std                      194.891310                  606.347851     0.488698
# min                        1.000000                    1.000000     0.000000
# 25%                        6.000000                   35.000000     0.000000
# 50%                       15.000000                   95.000000     0.000000
# 75%                       43.000000                  266.000000     1.000000
# max                     9989.000000                15841.000000     1.000000
#
# [8 rows x 58 columns]

# %% [markdown]
# * count — количество значений для каждого признака
# * mean — среднее значение
# * std — стандартное отклонение, значение которого показывает, на сколько в среднем отклоняются варианты от среднего значения
# * min — минимальное значение
# * 25% — значения, которые объект не превышает с вероятностью 25%
# * 50% — медиана, то есть значения, которые объект не превышает с вероятностью 25%
# * 75% — значения, которые объект не превышает с вероятностью 75%
# * max — максимальное значение

# %% [markdown]
# Построение диаграммы рассеивания для признаков.

# %%
seaborn.pairplot(data.iloc[numpy.random.choice(numpy.arange(data.shape[0]), size=1000, replace=False)], hue=' is_spam', diag_kind='hist')
pyplot.legend()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26996/1076261875.py in <module>
# ----> 1 seaborn.pairplot(data.iloc[numpy.random.choice(numpy.arange(data.shape[0]), size=1000, replace=False)], hue=' is_spam', diag_kind='hist')
#       2 pyplot.legend()
#
# D:\Program Files\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# D:\Program Files\anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2094     # Set up the PairGrid
#    2095     grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 2096     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    2097                     hue_order=hue_order, palette=palette, corner=corner,
#    2098                     height=height, aspect=aspect, dropna=dropna, **grid_kws)
#
# D:\Program Files\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# D:\Program Files\anaconda3\lib\site-packages\seaborn\axisgrid.py in __init__(self, data, hue, hue_order, palette, hue_kws, vars, x_vars, y_vars, corner, diag_sharey, height, aspect, layout_pad, despine, dropna, size)
#    1242             fig = plt.figure(figsize=figsize)
#    1243
# -> 1244         axes = fig.subplots(len(y_vars), len(x_vars),
#    1245                             sharex="col", sharey="row",
#    1246                             squeeze=False)
#
# D:\Program Files\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     469                 "parameter will become keyword-only %(removal)s.",
#     470                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 471         return func(*args, **kwargs)
#     472
#     473     return wrapper
#
# D:\Program Files\anaconda3\lib\site-packages\matplotlib\figure.py in subplots(self, nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw)
#     909             gridspec_kw = {}
#     910         gs = self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
# --> 911         axs = gs.subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#     912                           subplot_kw=subplot_kw)
#     913         return axs
#
# D:\Program Files\anaconda3\lib\site-packages\matplotlib\gridspec.py in subplots(self, sharex, sharey, squeeze, subplot_kw)
#     305                 subplot_kw["sharex"] = shared_with[sharex]
#     306                 subplot_kw["sharey"] = shared_with[sharey]
# --> 307                 axarr[row, col] = figure.add_subplot(
#     308                     self[row, col], **subplot_kw)
#     309
#
# D:\Program Files\anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#     782             projection_class, pkw = self._process_projection_requirements(
#     783                 *args, **kwargs)
# --> 784             ax = subplot_class_factory(projection_class)(self, *args, **pkw)
#     785             key = (projection_class, pkw)
#     786         return self._add_axes_internal(ax, key)
#
# D:\Program Files\anaconda3\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      34         """
#      35         # _axes_class is set in the subplot_class_factory
# ---> 36         self._axes_class.__init__(self, fig, [0, 0, 1, 1], **kwargs)
#      37         # This will also update the axes position.
#      38         self.set_subplotspec(SubplotSpec._from_subplot_args(fig, args))
#
# D:\Program Files\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     469                 "parameter will become keyword-only %(removal)s.",
#     470                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 471         return func(*args, **kwargs)
#     472
#     473     return wrapper
#
# D:\Program Files\anaconda3\lib\site-packages\matplotlib\axes\_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, **kwargs)
#     632
#     633         self._rasterization_zorder = None
# --> 634         self.cla()
#     635
#     636         # funcs used to format x and y - fall back on major formatters
#
# D:\Program Files\anaconda3\lib\site-packages\matplotlib\axes\_base.py in cla(self)
#    1243         self.containers = []
#    1244
# -> 1245         self.grid(False)  # Disable grid on init to use rcParameter
#    1246         self.grid(self._gridOn, which=mpl.rcParams['axes.grid.which'],
#    1247                   axis=mpl.rcParams['axes.grid.axis'])
#
# D:\Program Files\anaconda3\lib\site-packages\matplotlib\axes\_base.py in grid(self, b, which, axis, **kwargs)
#    3062         _api.check_in_list(['x', 'y', 'both'], axis=axis)
#    3063         if axis in ['x', 'both']:
# -> 3064             self.xaxis.grid(b, which=which, **kwargs)
#    3065         if axis in ['y', 'both']:
#    3066             self.yaxis.grid(b, which=which, **kwargs)
#
# D:\Program Files\anaconda3\lib\site-packages\matplotlib\axis.py in grid(self, b, which, **kwargs)
#    1431             gridkw['gridOn'] = (not self._major_tick_kw['gridOn']
#    1432                                 if b is TOGGLE else b)
# -> 1433             self.set_tick_params(which='major', **gridkw)
#    1434         self.stale = True
#    1435
#
# D:\Program Files\anaconda3\lib\site-packages\matplotlib\axis.py in set_tick_params(self, which, reset, **kw)
#     854             if which in ['major', 'both']:
#     855                 self._major_tick_kw.update(kwtrans)
# --> 856                 for tick in self.majorTicks:
#     857                     tick._apply_params(**kwtrans)
#     858             if which in ['minor', 'both']:
#
# D:\Program Files\anaconda3\lib\site-packages\matplotlib\axis.py in __get__(self, instance, cls)
#     605             if self._major:
#     606                 instance.majorTicks = []
# --> 607                 tick = instance._get_tick(major=True)
#     608                 instance.majorTicks.append(tick)
#     609                 return instance.majorTicks
#
# D:\Program Files\anaconda3\lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    2057         else:
#    2058             tick_kw = self._minor_tick_kw
# -> 2059         return XTick(self.axes, 0, major=major, **tick_kw)
#    2060
#    2061     def set_label_position(self, position):
#
# D:\Program Files\anaconda3\lib\site-packages\matplotlib\axis.py in __init__(self, *args, **kwargs)
#     420         super().__init__(*args, **kwargs)
#     421         # x in data coords, y in axes coords
# --> 422         self.tick1line.set(
#     423             xdata=[0], ydata=[0],
#     424             transform=self.axes.get_xaxis_transform(which="tick1"),
#
# D:\Program Files\anaconda3\lib\site-packages\matplotlib\artist.py in set(self, **kwargs)
#    1177         if move_color_to_start:
#    1178             kwargs = {"color": kwargs.pop("color"), **kwargs}
# -> 1179         return self.update(kwargs)
#    1180
#    1181     def findobj(self, match=None, include_self=True):
#
# D:\Program Files\anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1062                         raise AttributeError(f"{type(self).__name__!r} object "
#    1063                                              f"has no property {k!r}")
# -> 1064                     ret.append(func(v))
#    1065         if ret:
#    1066             self.pchanged()
#
# D:\Program Files\anaconda3\lib\site-packages\matplotlib\lines.py in set_marker(self, marker)
#    1168             arguments.
#    1169         """
# -> 1170         self._marker = MarkerStyle(marker, self._marker.get_fillstyle())
#    1171         self.stale = True
#    1172
#
# D:\Program Files\anaconda3\lib\site-packages\matplotlib\markers.py in __init__(self, marker, fillstyle)
#     234         self._marker_function = None
#     235         self._set_fillstyle(fillstyle)
# --> 236         self._set_marker(marker)
#     237
#     238     def _recache(self):
#
# D:\Program Files\anaconda3\lib\site-packages\matplotlib\markers.py in _set_marker(self, marker)
#     333         if not isinstance(marker, MarkerStyle):
#     334             self._marker = marker
# --> 335             self._recache()
#     336
#     337     def get_path(self):
#
# D:\Program Files\anaconda3\lib\site-packages\matplotlib\markers.py in _recache(self)
#     250         # markers.
#     251         self._filled = self._fillstyle != 'none'
# --> 252         self._marker_function()
#     253
#     254     def __bool__(self):
#
# D:\Program Files\anaconda3\lib\site-packages\matplotlib\markers.py in _set_tickdown(self)
#     702
#     703     def _set_tickdown(self):
# --> 704         self._transform = Affine2D().scale(1.0, -1.0)
#     705         self._snap_threshold = 1.0
#     706         self._filled = False
#
# D:\Program Files\anaconda3\lib\site-packages\matplotlib\transforms.py in scale(self, sx, sy)
#    2035         self._mtx[1, 1] *= sy
#    2036         self._mtx[1, 2] *= sy
# -> 2037         self.invalidate()
#    2038         return self
#    2039
#
# D:\Program Files\anaconda3\lib\site-packages\matplotlib\transforms.py in invalidate(self)
#     176         if self.is_affine:
#     177             value = self.INVALID_AFFINE
# --> 178         return self._invalidate_internal(value, invalidating_node=self)
#     179
#     180     def _invalidate_internal(self, value, invalidating_node):
#
# D:\Program Files\anaconda3\lib\site-packages\matplotlib\transforms.py in _invalidate_internal(self, value, invalidating_node)
#     198             self._invalid = value
#     199
# --> 200             for parent in list(self._parents.values()):
#     201                 # Dereference the weak reference
#     202                 parent = parent()
#
# KeyboardInterrupt:

# %%
data.corr().where(numpy.triu(data.corr() > 0.3, k = 1)).stack().sort_values(ascending = False)
# Out:
#  word_freq_857       word_freq_415        0.996066
#                      word_freq_direct     0.848021
#  word_freq_415       word_freq_direct     0.845359
#  word_freq_telnet    word_freq_857        0.737555
#                      word_freq_415        0.735187
#                                             ...
#  word_freq_650       char_freq_(          0.313835
#  word_freq_000       char_freq_$          0.310971
#  word_freq_you       word_freq_your       0.304986
#  word_freq_857       char_freq_(          0.304679
#  word_freq_415       char_freq_(          0.303606
# Length: 70, dtype: float64

# %%
seaborn.heatmap(data.corr(), square=True, vmin=-1, vmax=1, cmap='cool')
pass

# %% [markdown]
# По матрице корреляции видно, что сильнейшую связь образуют признаки 'word_freq_857' и 'word_freq_415', так как они имеют наибольший коэффициент корелляции 0,996.

# %% [markdown]
# # Обработка категориальных признаков

# %% [markdown]
# Все признаки датасета являются количественными, класс объекта является категориальным признаком, принимающим бинарные значения.

# %%
data[' is_spam'].value_counts()
# Out:
# 0    2788
# 1    1813
# Name:  is_spam, dtype: int64

# %% [markdown]
# Для всех объектов категориальный признак определён, следовательно пропущеных значений нет.

# %% [markdown]
# # Нормализация количественных признаков
# Перед использованием алгоритмов машинного обучения лучше нормализовать данные.

# %%
normalization = [i for i in data.columns if i != ' is_spam']
data_normal = (data[normalization] - data[normalization].mean(axis = 0))/data[normalization].std(axis = 0)
data_normal.describe()
# Out:
#        word_freq_make    word_freq_address    word_freq_all    word_freq_3d   \
# count     4.601000e+03         4.601000e+03     4.601000e+03    4.601000e+03
# mean     -1.783753e-15         1.614275e-15    -4.023346e-15    2.784820e-15
# std       1.000000e+00         1.000000e+00     1.000000e+00    1.000000e+00
# min      -3.423965e-01        -1.650540e-01    -5.567001e-01   -4.689449e-02
# 25%      -3.423965e-01        -1.650540e-01    -5.567001e-01   -4.689449e-02
# 50%      -3.423965e-01        -1.650540e-01    -5.567001e-01   -4.689449e-02
# 75%      -3.423965e-01        -1.650540e-01     2.763971e-01   -4.689449e-02
# max       1.452542e+01         1.089978e+01     9.559480e+00    3.063795e+01
#
#         word_freq_our    word_freq_over    word_freq_remove   \
# count     4.601000e+03      4.601000e+03        4.601000e+03
# mean      8.230647e-15     -5.586828e-16        3.989081e-15
# std       1.000000e+00      1.000000e+00        1.000000e+00
# min      -4.642639e-01     -3.502281e-01       -2.917622e-01
# 25%      -4.642639e-01     -3.502281e-01       -2.917622e-01
# 50%      -4.642639e-01     -3.502281e-01       -2.917622e-01
# 75%       1.007811e-01     -3.502281e-01       -2.917622e-01
# max       1.440534e+01      2.112341e+01        1.828062e+01
#
#         word_freq_internet    word_freq_order    word_freq_mail   ...  \
# count          4.601000e+03       4.601000e+03      4.601000e+03  ...
# mean           1.908758e-15      -6.747265e-15     -4.863650e-16  ...
# std            1.000000e+00       1.000000e+00      1.000000e+00  ...
# min           -2.625330e-01      -3.232672e-01     -3.713240e-01  ...
# 25%           -2.625330e-01      -3.232672e-01     -3.713240e-01  ...
# 50%           -2.625330e-01      -3.232672e-01     -3.713240e-01  ...
# 75%           -2.625330e-01      -3.232672e-01     -1.231679e-01  ...
# max            2.743827e+01       1.855577e+01      2.782542e+01  ...
#
#         word_freq_conference    char_freq_;    char_freq_(    char_freq_[   \
# count            4.601000e+03   4.601000e+03   4.601000e+03   4.601000e+03
# mean            -1.853953e-15   4.622036e-15   1.831494e-15   1.006657e-15
# std              1.000000e+00   1.000000e+00   1.000000e+00   1.000000e+00
# min             -1.115341e-01  -1.584361e-01  -5.142507e-01  -1.551808e-01
# 25%             -1.115341e-01  -1.584361e-01  -5.142507e-01  -1.551808e-01
# 50%             -1.115341e-01  -1.584361e-01  -2.738264e-01  -1.551808e-01
# 75%             -1.115341e-01  -1.584361e-01   1.811304e-01  -1.551808e-01
# max              3.488597e+01   1.785190e+01   3.555679e+01   3.715028e+01
#
#         char_freq_!    char_freq_$    char_freq_#   \
# count   4.601000e+03   4.601000e+03   4.601000e+03
# mean    1.949236e-15  -4.799851e-15   9.303939e-17
# std     1.000000e+00   1.000000e+00   1.000000e+00
# min    -3.298764e-01  -3.083214e-01  -1.030372e-01
# 25%    -3.298764e-01  -3.083214e-01  -1.030372e-01
# 50%    -3.298764e-01  -3.083214e-01  -1.030372e-01
# 75%     5.630838e-02  -9.683788e-02  -1.030372e-01
# max     3.948762e+01   2.410583e+01   4.608158e+01
#
#         capital_run_length_average    capital_run_length_longest   \
# count                  4.601000e+03                  4.601000e+03
# mean                  -8.306886e-16                 -7.698085e-16
# std                    1.000000e+00                  1.000000e+00
# min                   -1.321017e-01                 -2.625709e-01
# 25%                   -1.135701e-01                 -2.369156e-01
# 50%                   -9.188672e-02                 -1.907360e-01
# 75%                   -4.681818e-02                 -4.706618e-02
# max                    3.458328e+01                  5.098651e+01
#
#         capital_run_length_total
# count                4.601000e+03
# mean                -3.658838e-16
# std                  1.000000e+00
# min                 -4.655567e-01
# 25%                 -4.094832e-01
# 50%                 -3.105301e-01
# 75%                 -2.851381e-02
# max                  2.565806e+01
#
# [8 rows x 57 columns]

# %% [markdown]
# Проведена стандартизация - линейное преобразование, приводящее все значения к нулевому среднему и единичному стандартному отклонению.
# # Разбиение классов на обучающую и тестовую выборку

# %%
dataX = data.drop(' is_spam', axis=1)
dataY = data[' is_spam']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(dataX, dataY, test_size = 0.25, random_state = 42)
N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 
print('Size train: ',N_train)
print('Size test: ', N_test)
# Out:
# Size train:  3450
# Size test:  1151

# %% [markdown]
# # Обучение модели
# Метод K-ближайших соседей, с количесвтом соседей - 5.

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_4 = KNeighborsClassifier(n_neighbors = 10)
knn_4.fit(X_train, y_train)
knn_training_predict = knn_4.score(X_train, y_train)
knn_test_predict = knn_4.score(X_test, y_test)
err_train = numpy.mean(y_train != knn_4.predict(X_train))
err_test  = numpy.mean(y_test  != knn_4.predict(X_test))
print("Accuracy - Train : {:.2f}, Test: {:.2f}. ".format(knn_training_predict, knn_test_predict))
print("Error - Train : {:.2f}, Test: {:.2f}. ".format(err_train, err_test))
# Out:
# Accuracy - Train : 0.83, Test: 0.77.
# Error - Train : 0.17, Test: 0.23.

# %% [markdown]
# Метод K-ближайших соседей, с количесвтом соседей - 10.

# %%
knn_10 = KNeighborsClassifier(n_neighbors = 10)
knn_10.fit(X_train, y_train)
knn_training_predict = knn_10.score(X_train, y_train)
knn_test_predict = knn_10.score(X_test, y_test)
err_train = numpy.mean(y_train != knn_10.predict(X_train))
err_test  = numpy.mean(y_test  != knn_10.predict(X_test))
print("Accuracy - Train : {:.2f}, Test: {:.2f}. ".format(knn_training_predict, knn_test_predict))
print("Error - Train : {:.2f}, Test: {:.2f}. ".format(err_train, err_test))
# Out:
# Accuracy - Train : 0.83, Test: 0.77.
# Error - Train : 0.17, Test: 0.23.

# %% [markdown]
# При изменении количесвта соседей точность модели в выборках не изменилась.

# %% [markdown]
# # Выводы
# В данном практическом задании была решена задача классификации писем на спам и не спам по набору признаков с помощью обучения модели, натренированной методом К-ближайших соседей.

# %% [markdown]
# Перед тем как тренировать модель были проведены следующие действия:
# * вычисление и анализ основных характеристик
# * проверка на наличие пропущенных значений
# * нормализация данных методом стандартизации
# * разбиение данных на тестовую и тренировочную выборку
# * выбор алгоритма классификации и проверка качества полученной модели
